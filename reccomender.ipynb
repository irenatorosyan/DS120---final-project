# %%
# technical code 
# some middle steps are outputed, thus the code slightly differs from the code used in the website
# the syntax of giving input and getting output also differs

# %%
import numpy as np
import pandas as pd
import random

# %%
# reading data

recipes_df = pd.read_csv('allrecipes.csv', usecols = ["TITLES", "LINKS"])
recipes_df["recipeId"] = recipes_df.index+1
recipes_df = recipes_df[["recipeId", "TITLES", "LINKS"]]
recipes_df.head()
# Out:
#    recipeId                             TITLES  \
# 0         1       How to Make the Best Oatmeal
# 1         2                   Spinach Frittata
# 2         3  Orange-Spiced Whole Wheat Muffins
# 3         4              Tuscan Scrambled Eggs
# 4         5                 Crispy Hash Browns
#
#                                                LINKS
# 0  https://www.simplyrecipes.com/recipes/how_to_m...
# 1  https://www.simplyrecipes.com/recipes/spinach_...
# 2  https://www.simplyrecipes.com/recipes/orange_s...
# 3  https://www.simplyrecipes.com/recipes/tuscan_s...
# 4  https://www.simplyrecipes.com/recipes/crispy_h...

# %%
# reading data

ratings_df = pd.read_csv('ratings.csv')
ratings_df.head()
# Out:
#    userId  recipeId  rating
# 0       1       527       3
# 1       1       238       3
# 2       1       400       2
# 3       1        88       3
# 4       1       648       5

# %%
# getting the input from the user

userInput = [
            {'TITLES':'Zucchini Ricotta Frittata', 'rating':5},
            {'TITLES':'Vegan Chocolate Pudding', 'rating':5},
            {'TITLES':'Mediterranean Mezze Platte', 'rating':2},
            {'TITLES':"Pecan Pralines", 'rating':0},
            {'TITLES':'Sous Vide Sesame Chicken', 'rating':4}
         ] 

inputRecipes = pd.DataFrame(userInput)
inputRecipes
# Out:
#                        TITLES  rating
# 0   Zucchini Ricotta Frittata       5
# 1     Vegan Chocolate Pudding       5
# 2  Mediterranean Mezze Platte       2
# 3              Pecan Pralines       0
# 4    Sous Vide Sesame Chicken       4

# %%
# filtering the recipes by title

inputId = recipes_df[recipes_df['TITLES'].isin(inputRecipes['TITLES'].tolist())]
inputId
# Out:
#      recipeId                     TITLES  \
# 13         14  Zucchini Ricotta Frittata
# 248       249    Vegan Chocolate Pudding
# 506       507             Pecan Pralines
# 776       777   Sous Vide Sesame Chicken
#
#                                                  LINKS
# 13   https://www.simplyrecipes.com/recipes/zucchini...
# 248  https://www.simplyrecipes.com/recipes/vegan_ch...
# 506    https://www.simplyrecipes.com/recipes/pralines/
# 776  https://www.simplyrecipes.com/recipes/sous_vid...

# %%
# merging so we can get the recipeId

inputRecipes = pd.merge(inputId, inputRecipes)
inputRecipes
# Out:
#    recipeId                     TITLES  \
# 0        14  Zucchini Ricotta Frittata
# 1       249    Vegan Chocolate Pudding
# 2       507             Pecan Pralines
# 3       777   Sous Vide Sesame Chicken
#
#                                                LINKS  rating
# 0  https://www.simplyrecipes.com/recipes/zucchini...       5
# 1  https://www.simplyrecipes.com/recipes/vegan_ch...       5
# 2    https://www.simplyrecipes.com/recipes/pralines/       0
# 3  https://www.simplyrecipes.com/recipes/sous_vid...       4

# %%
# filtering out users that gave review on for the same recipes 

userSubset = ratings_df[ratings_df['recipeId'].isin(inputRecipes['recipeId'].tolist())]
userSubset.head()
# Out:
#      userId  recipeId  rating
# 28        1        14       2
# 124       1       249       4
# 172       1       777       1
# 218       1       507       2
# 481       2       507       2

# %%
userSubsetGroup = userSubset.groupby(['userId'])

# %%
# giving priority to the users with more recipes in common

userSubsetGroup = sorted(userSubsetGroup,  key=lambda x: len(x[1]), reverse=True)

# %%
userSubsetGroup = userSubsetGroup[0:100]

# %%
# calculating Pearson Correlation

# Pearson Correlation formula
# https://www.socscistatistics.com/tests/pearson/#:~:text=The%20Pearson%20correlation%20coefficient%20is,means%20a%20perfect%20negataive%20correlation.

# the key is the userId and the value is the coefficient
pearsonCorrelationDict = {}

for name, group in userSubsetGroup:
    
    # sorting the input and current user group
    group = group.sort_values(by='recipeId')
    inputRecipes = inputRecipes.sort_values(by='recipeId')
    
    # total similar recipes
    nRatings = len(group)
    
    # review scores for the recipes
    temp_df = inputRecipes[inputRecipes['recipeId'].isin(group['recipeId'].tolist())]
    
    tempRatingList = temp_df['rating'].tolist()
    tempGroupList = group['rating'].tolist()
    
    # the calculation
    Sxx = sum([i**2 for i in tempRatingList]) - pow(sum(tempRatingList),2)/float(nRatings)
    Syy = sum([i**2 for i in tempGroupList]) - pow(sum(tempGroupList),2)/float(nRatings)
    Sxy = sum( i*j for i, j in zip(tempRatingList, tempGroupList)) - sum(tempRatingList)*sum(tempGroupList)/float(nRatings)
    
    # if the denominator is not zero, divide, otherwise the correlation is 0
    if Sxx != 0 and Syy != 0:
        pearsonCorrelationDict[name] = Sxy/np.sqrt(Sxx*Syy)
    else:
        pearsonCorrelationDict[name] = 0

# %%
pearsonCorrelationDict
# Out:
# {21: -0.8346223261119858,
#  109: 0.8677218312746247,
#  236: -0.4338609156373123,
#  299: -0.36563621206356534,
#  323: 0.8574929257125441,
#  328: -0.5547950410914818,
#  377: 0.2666739829256819,
#  28: 0.6933752452815364,
#  40: 0.3273268353539886,
#  43: 0.6546536707079774,
#  53: 0.3273268353539887,
#  73: 0.32732683535398854,
#  94: 0.944911182523068,
#  143: -0.826033187630902,
#  155: -0.8170571691028833,
#  162: -0.998625428903524,
#  166: 0.944911182523068,
#  169: -0.3711537444790452,
#  172: -0.6546536707079772,
#  229: -0.6185895741317419,
#  235: -0.3273268353539887,
#  238: -0.9449111825230633,
#  239: -0.7559289460184544,
#  241: -0.6933752452815368,
#  258: 0.5000000000000002,
#  263: -0.654653670707977,
#  287: -0.7559289460184546,
#  292: 0.6185895741317419,
#  313: 0.9449111825230679,
#  345: -0.5,
#  352: 0.944911182523068,
#  365: 0.3273268353539886,
#  370: 0.49999999999999994,
#  380: 0.6546536707079772,
#  382: -0.8170571691028833,
#  386: -0.998625428903524,
#  390: -0.6546536707079772,
#  393: -0.944911182523068,
#  408: -0.4999999999999982,
#  422: -0.9449111825230654,
#  426: 0.1889822365046136,
#  432: -0.8660254037844387,
#  448: -0.32732683535398854,
#  476: 0.6546536707079772,
#  478: -0.9819805060619657,
#  479: -0.49999999999999994,
#  3: -1.0,
#  4: 1.0,
#  6: 0,
#  7: 1.0,
#  10: 1.0,
#  19: 0,
#  23: 0,
#  26: 1.0,
#  29: 0,
#  37: 1.0,
#  42: 1.0,
#  45: 1.0,
#  47: -1.0,
#  49: 0,
#  50: 0,
#  52: 1.0,
#  58: -1.0,
#  64: 1.0,
#  66: 1.0,
#  68: 0,
#  69: -1.0,
#  70: 1.0,
#  74: -1.0,
#  75: 0,
#  76: 1.0,
#  77: -1.0,
#  79: 0,
#  85: -1.0,
#  87: 1.0,
#  96: 0,
#  102: 1.0,
#  104: -1.0,
#  106: -1.0,
#  108: -1.0,
#  114: -1.0,
#  118: -1.0,
#  120: -1.0,
#  121: 0,
#  123: 1.0,
#  126: 1.0,
#  131: 0,
#  136: 1.0,
#  141: 0,
#  146: -1.0,
#  148: 1.0,
#  149: 1.0,
#  151: 0,
#  152: -1.0,
#  159: 1.0,
#  160: 1.0,
#  163: 1.0,
#  176: 1.0,
#  177: 0,
#  178: 0}

# %%
pearsonDF = pd.DataFrame.from_dict(pearsonCorrelationDict, orient='index')
pearsonDF.head()
# Out:
#             0
# 21  -0.834622
# 109  0.867722
# 236 -0.433861
# 299 -0.365636
# 323  0.857493

# %%
pearsonDF.columns = ['similarityIndex']
pearsonDF['userId'] = pearsonDF.index
pearsonDF.index = range(len(pearsonDF))
pearsonDF.head()
# Out:
#    similarityIndex  userId
# 0        -0.834622      21
# 1         0.867722     109
# 2        -0.433861     236
# 3        -0.365636     299
# 4         0.857493     323

# %%
topUsers=pearsonDF.sort_values(by='similarityIndex', ascending=False)[0:50]
topUsers.head()
# Out:
#     similarityIndex  userId
# 50              1.0      10
# 64              1.0      66
# 85              1.0     126
# 84              1.0     123
# 76              1.0     102

# %%
topUsersRating = topUsers.merge(ratings_df, left_on='userId', right_on='userId', how='inner')
topUsersRating.head()
# Out:
#    similarityIndex  userId  recipeId  rating
# 0              1.0      10       284       2
# 1              1.0      10       598       5
# 2              1.0      10        61       3
# 3              1.0      10       419       3
# 4              1.0      10       816       1

# %%
# Multiplying the similarity by the rating

topUsersRating['weightedRating'] = topUsersRating['similarityIndex']*topUsersRating['rating']
topUsersRating.head()
# Out:
#    similarityIndex  userId  recipeId  rating  weightedRating
# 0              1.0      10       284       2             2.0
# 1              1.0      10       598       5             5.0
# 2              1.0      10        61       3             3.0
# 3              1.0      10       419       3             3.0
# 4              1.0      10       816       1             1.0

# %%
tempTopUsersRating = topUsersRating.groupby('recipeId').sum()[['similarityIndex','weightedRating']]
tempTopUsersRating.columns = ['sum_similarityIndex','sum_weightedRating']
tempTopUsersRating.head()
# Out:
#           sum_similarityIndex  sum_weightedRating
# recipeId
# 1                   11.295561           44.840026
# 2                    8.766365           26.465896
# 3                    6.926892           21.743606
# 4                   15.754663           36.705773
# 5                   12.440044           35.981033

# %%
recommendation_df = pd.DataFrame()

# %%
# taking the weighted average

recommendation_df['weighted average recommendation score'] = tempTopUsersRating['sum_weightedRating']/tempTopUsersRating['sum_similarityIndex']
recommendation_df['recipeId'] = tempTopUsersRating.index
recommendation_df.head()
# Out:
#           weighted average recommendation score  recipeId
# recipeId
# 1                                      3.969703         1
# 2                                      3.019027         2
# 3                                      3.139013         3
# 4                                      2.329836         4
# 5                                      2.892356         5

# %%
# reccomended recipes

recommendation_df = recommendation_df.sort_values(by='weighted average recommendation score', ascending=False)
recommendation_df.head()
# Out:
#           weighted average recommendation score  recipeId
# recipeId
# 777                                    4.366387       777
# 418                                    4.143185       418
# 824                                    4.099754       824
# 380                                    4.062545       380
# 86                                     4.058152        86

# %%
recipes_df.loc[recipes_df['recipeId'].isin(recommendation_df.head(20)['recipeId'].tolist())]
# Out:
#      recipeId                                            TITLES  \
# 0           1                      How to Make the Best Oatmeal
# 85         86                          Thousand Island Dressing
# 204       205                                  Carrot Top Pesto
# 268       269                        Strawberry Rhubarb Terrine
# 313       314                                 Aviation Cocktail
# 362       363                                  Fresh Pea Hummus
# 379       380                                   Cranberry Salsa
# 397       398                               Classic Cheese Ball
# 408       409              Corn, Crab, and Old Bay Deviled Eggs
# 417       418                                     Potato Latkes
# 467       468                            Strawberry Rhubarb Pie
# 482       483                        Chocolate-Covered Pretzels
# 594       595                         BBQ Grilled Chicken Wings
# 622       623                       Sausage Breakfast Casserole
# 699       700                            Instant Pot Beef Chili
# 718       719                          Sheet Pan Fish and Chips
# 776       777                          Sous Vide Sesame Chicken
# 823       824     Roast Turkey Breast with Roasted Garlic Gravy
# 845       846                            Cuban-Style Roast Pork
# 848       849  Sesame-Crusted Pork Cutlets with Crispy Shallots
#
#                                                  LINKS
# 0    https://www.simplyrecipes.com/recipes/how_to_m...
# 85   https://www.simplyrecipes.com/recipes/thousand...
# 204  https://www.simplyrecipes.com/recipes/carrot_t...
# 268  https://www.simplyrecipes.com/recipes/strawber...
# 313  https://www.simplyrecipes.com/recipes/aviation...
# 362  https://www.simplyrecipes.com/recipes/spring_p...
# 379  https://www.simplyrecipes.com/recipes/cranberr...
# 397  https://www.simplyrecipes.com/recipes/classic_...
# 408  https://www.simplyrecipes.com/recipes/corn_cra...
# 417  https://www.simplyrecipes.com/recipes/potato_l...
# 467  https://www.simplyrecipes.com/recipes/strawber...
# 482  https://www.simplyrecipes.com/recipes/chocolat...
# 594  https://www.simplyrecipes.com/recipes/barbecue...
# 622  https://www.simplyrecipes.com/recipes/sausage_...
# 699  https://www.simplyrecipes.com/recipes/pressure...
# 718  https://www.simplyrecipes.com/recipes/sheet_pa...
# 776  https://www.simplyrecipes.com/recipes/sous_vid...
# 823  https://www.simplyrecipes.com/recipes/roast_tu...
# 845  https://www.simplyrecipes.com/recipes/cuban_st...
# 848  https://www.simplyrecipes.com/recipes/sesame_c...
